# %%
# list = [output for item in iterable if condition]

# sq = []

# for i in range(6):
#     sq.append(i*i)

sq = [i*i for i in range(6) if i%2 != 0] # list comprehension

print(sq)
# Out:
# [0, 1, 4, 9, 16, 25]

# %%
l = [-2, -3, 4, 0, 6, -1]

newL = [0 if val<0 else val for val in l]

print(newL)
# Out:
# [0, 0, 4, 0, 6, 0]
