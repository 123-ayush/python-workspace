# %%
s = {1,2,2,3,4}

print(s)

# to create empy set

new_Set = set()

print(new_Set)
# Out:
# {1, 2, 3, 4}
# set()

# %%
# Methods

# 1. s.add(val) -> add new value
# 2. s.remove(val) -> remove a new val 
# 3. s.clear() -> to empty set
# 4. s.pop() -> remove random value from set
# 5. s.union(s2) -> union of two set
# 6. s.intersection(s2) -> intersection of two set

s1 = {1,2,3,4,5}
s2 = {4,5,6,7,8}

print(s1.intersection(s2))

print(s2)
# Out:
# {4, 5}
# {4, 5, 6, 7, 8}

# %%
# no indexing in sets
