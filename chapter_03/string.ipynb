# %%
word = "python"
greet = "hey "
sent = greet + word # concatenation

print(len(word))
print(sent)

# indexing (both +ve and -ve)

print(sent[4])

# strings are immutable

# slicing

sub = word[2:4]

print(sub)
# Out:
# 6
# hey python
# p
# th

# %%
# string formatting

a = "ayush"
b = 20

print(f"Hey! my name is {a} and I am {b} years old.")
# Out:
# Hey! my name is ayush and I am 20 years old.
