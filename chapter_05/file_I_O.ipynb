# %% [markdown]
# File Operations

# %%
# Open operation

#   f = open("file_name/path", "modes")
#   Modes:
        # 1. "r" -> read
            # a. f.read() -> to read all data
            # b. f.readline() -> read line by line
            # c. f.read(1) -> to read character by character
        # 2. "w" -> write

f = open("example.txt", "r")
data = f.read()

print(data, type(data))

f.close()


f = open("example.txt", "w")
f.write("The ")
# Out:
# my name is ayush
#  <class 'str'>
