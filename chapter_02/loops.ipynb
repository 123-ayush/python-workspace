# %%
count = 0
while (count<=5):
    print(count)
    count+=1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(1,6,2):  #(start, stop, step)
    print(i)
# Out:
# 1
# 3
# 5

# %%
num = 2
for i in range(1,11):
    print(f"{num} X {i} = {num*i}")
# Out:
# 2 X 1 = 2
# 2 X 2 = 4
# 2 X 3 = 6
# 2 X 4 = 8
# 2 X 5 = 10
# 2 X 6 = 12
# 2 X 7 = 14
# 2 X 8 = 16
# 2 X 9 = 18
# 2 X 10 = 20

# %%
# Print table without multiple of 3 till 15

num = 2
for i in range(1,16):
    if(i%3 == 0):
        continue
    elif(i > 15):
        break
    else:
        print(f"{num} X {i} = {num*i}")
# Out:
# 2 X 1 = 2
# 2 X 2 = 4
# 2 X 4 = 8
# 2 X 5 = 10
# 2 X 7 = 14
# 2 X 8 = 16
# 2 X 10 = 20
# 2 X 11 = 22
# 2 X 13 = 26
# 2 X 14 = 28

# %%
name = "ayush ahlawat"

for c in name:
    print(c)
# Out:
# a
# y
# u
# s
# h
#
# a
# h
# l
# a
# w
# a
# t
